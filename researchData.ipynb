# %%
import getfile
import pandas as pd
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
langs = ['C', 'C++', 'Java', 'Python', 'PHP']
students = [23,17,35,29,12]
ax.bar(langs,students)
plt.show()

# %%
pdObj = pd.read_csv("testCSV.csv", header=0, index_col=1)
# Out:
#                             Heap Memory
# Time
# 2022-07-27 19:42:56.445592        40568
# 2022-07-27 19:43:01.463601        40568
# 2022-07-27 19:43:06.601140        39504
# 2022-07-27 19:43:11.397891        39504
# 2022-07-27 19:43:16.414560        39504
# ...                                 ...
# 2022-07-29 11:16:52.297659        40600
# 2022-07-29 11:16:57.211755        40600
# 2022-07-29 11:17:02.251813        40600
# 2022-07-29 11:17:07.247199        40600
# 2022-07-29 11:17:12.265385        40600
#
# [19008 rows x 1 columns]

# %%
pdObj.shape
# Out:
# (19008, 1)

# %%
pdObj.describe()
# Out:
#         Heap Memory
# count  19008.000000
# mean   40727.013468
# std     1342.374587
# min    36368.000000
# 25%    39504.000000
# 50%    40568.000000
# 75%    41664.000000
# max    45184.000000

# %%
plt.figure(figsize=(20,8))
plt.plot(pdObj["Heap Memory"][:50])
plt.xticks(rotation = 90)
# plt.xlim(50)
plt.show()

# %%
memData = pdObj["Heap Memory"]
dateData = pdObj.index
dateData = pd.to_datetime(dateData)
memData.describe()
# Out:
# count    19008.000000
# mean     40727.013468
# std       1342.374587
# min      36368.000000
# 25%      39504.000000
# 50%      40568.000000
# 75%      41664.000000
# max      45184.000000
# Name: Heap Memory, dtype: float64

# %%
dateData
# Out:
# DatetimeIndex(['2022-07-27 19:42:56.445592', '2022-07-27 19:43:01.463601',
#                '2022-07-27 19:43:06.601140', '2022-07-27 19:43:11.397891',
#                '2022-07-27 19:43:16.414560', '2022-07-27 19:43:21.432223',
#                '2022-07-27 19:43:26.520619', '2022-07-27 19:43:31.466403',
#                '2022-07-27 19:43:36.498363', '2022-07-27 19:43:41.401000',
#                ...
#                '2022-07-29 11:16:27.311719', '2022-07-29 11:16:32.242486',
#                '2022-07-29 11:16:37.248163', '2022-07-29 11:16:42.260891',
#                '2022-07-29 11:16:47.280319', '2022-07-29 11:16:52.297659',
#                '2022-07-29 11:16:57.211755', '2022-07-29 11:17:02.251813',
#                '2022-07-29 11:17:07.247199', '2022-07-29 11:17:12.265385'],
#               dtype='datetime64[ns]', name='Time', length=19008, freq=None)

# %%
pdObj["seconds"]=list(map(lambda x:x.second,dateData))
pdObj
# Out:
#                             Heap Memory  seconds
# Time
# 2022-07-27 19:42:56.445592        40568       56
# 2022-07-27 19:43:01.463601        40568        1
# 2022-07-27 19:43:06.601140        39504        6
# 2022-07-27 19:43:11.397891        39504       11
# 2022-07-27 19:43:16.414560        39504       16
# ...                                 ...      ...
# 2022-07-29 11:16:52.297659        40600       52
# 2022-07-29 11:16:57.211755        40600       57
# 2022-07-29 11:17:02.251813        40600        2
# 2022-07-29 11:17:07.247199        40600        7
# 2022-07-29 11:17:12.265385        40600       12
#
# [19008 rows x 2 columns]
